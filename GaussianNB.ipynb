# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs

# %%
X, y = make_blobs(100, 2, centers=2, random_state=2, cluster_std=1.5)
plt.scatter(X[:, 0], X[:, 1], c=y, s=50, cmap='RdBu');

# %%
from sklearn.naive_bayes import GaussianNB
model = GaussianNB()
model.fit(X, y);

# %%
rng = np.random.RandomState(0)
#Xnew = [-6, -14] + [14, 18] * rng.rand(2000, 2)
Xnew = [-9, -6] + [12, 4] * rng.rand(10, 2)
ynew = model.predict(Xnew)
Xnew
# Out:
# array([[-2.41423795, -3.13924253],
#        [-1.76683949, -3.82046727],
#        [-3.91614241, -3.41642355],
#        [-3.74895346, -2.432908  ],
#        [ 2.56395313, -4.46623392],
#        [ 0.50070046, -3.88442032],
#        [-2.18346527, -2.29761345],
#        [-8.1475673 , -5.6514828 ],
#        [-8.75737923, -2.66952062],
#        [ 0.33788101, -2.51995141]])

# %%
plt.scatter(X[:, 0], X[:, 1], c=y, s=50, cmap='RdBu')
lim = plt.axis()
plt.scatter(Xnew[:, 0], Xnew[:, 1], c=ynew, s=80, cmap='RdBu', alpha=0.2)
plt.axis(lim);
ynew
# Out:
# array([1, 1, 1, 1, 1, 1, 1, 0, 1, 1])

# %%
yprob = model.predict_proba(Xnew)
yprob[-8:].round(2)
# Out:
# array([[0.04, 0.96],
#        [0.  , 1.  ],
#        [0.  , 1.  ],
#        [0.  , 1.  ],
#        [0.  , 1.  ],
#        [0.99, 0.01],
#        [0.  , 1.  ],
#        [0.  , 1.  ]])
